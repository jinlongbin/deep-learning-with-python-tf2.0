# %%
from tensorflow import keras
keras.__version__
# Out:
# '2.2.4-tf'

# %%
import tensorflow as tf   #tf 2.0 GPU error 해결법
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.7)

sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))

# %% [markdown]
# # LSTM으로 텍스트 생성하기
#
# 이 노트북은 [케라스 창시자에게 배우는 딥러닝](https://tensorflow.blog/deep-learning-with-python/) 책의 8장 1절의 코드 예제입니다. 책에는 더 많은 내용과 그림이 있습니다. 이 노트북에는 소스 코드에 관련된 설명만 포함합니다. 이 노트북의 설명은 케라스 버전 2.2.2에 맞추어져 있습니다. 케라스 최신 버전이 릴리스되면 노트북을 다시 테스트하기 때문에 설명과 코드의 결과가 조금 다를 수 있습니다.
#
# ----
#
# [...]
#
# ## 글자 수준의 LSTM 텍스트 생성 모델 구현
#
# 이런 아이디어를 케라스로 구현해 보죠. 먼저 언어 모델을 학습하기 위해 많은 텍스트 데이터가 필요합니다. 위키피디아나 반지의 제왕처럼 아주 큰 텍스트 파일이나 텍스트 파일의 묶음을 사용할 수 있습니다. 이 예에서는 19세기 후반 독일의 철학자 니체의 글을 사용하겠습니다(영어로 번역된 글입니다). 학습할 언어 모델은 일반적인 영어 모델이 아니라 니체의 문체와 특정 주제를 따르는 모델일 것입니다.

# %% [markdown]
# ## 데이터 전처리
#
# 먼저 말뭉치를 다운로드하고 소문자로 바꿉니다:

# %%
from tensorflow import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# 말뭉치 크기: 600893

# %%
type(text)
# Out:
# str

# %% [markdown]
# 그 다음 `maxlen` 길이를 가진 시퀀스를 중복하여 추출합니다. 추출된 시퀀스를 원-핫 인코딩으로 변환하고 크기가 `(sequences, maxlen, unique_characters)`인 3D 넘파이 배열 `x`로 합칩니다. 동시에 훈련 샘플에 상응하는 타깃을 담은 배열 `y`를 준비합니다. 타깃은 추출된 시퀀스 다음에 오는 원-핫 인코딩된 글자입니다.

# %%
# 60개 글자로 된 시퀀스를 추출합니다.
maxlen = 60

# 세 글자씩 건너 뛰면서 새로운 시퀀스를 샘플링합니다.
step = 3

# 추출한 시퀀스를 담을 리스트
sentences = []

# 타깃(시퀀스 다음 글자)을 담을 리스트
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))

# 말뭉치에서 고유한 글자를 담은 리스트
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
char_indices = dict((char, chars.index(char)) for char in chars)

# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿉니다.
print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 58
# 벡터화...

# %% [markdown]
# ## 네트워크 구성
#
# 이 네트워크는 하나의 `LSTM` 층과 그 뒤에 `Dense` 분류기가 뒤따릅니다. 분류기는 가능한 모든 글자에 대한 소프트맥스 출력을 만듭니다. 순환 신경망이 시퀀스 데이터를 생성하는 유일한 방법은 아닙니다. 최근에는 1D 컨브넷도 이런 작업에 아주 잘 들어 맞는다는 것이 밝혀졌습니다.

# %%
from tensorflow.keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0909 19:57:45.934534  3144 tf_logging.py:161] <tensorflow.python.keras.layers.recurrent.UnifiedLSTM object at 0x000001B394EBE278>: Note that this layer is not optimized for performance. Please use tf.keras.layers.CuDNNLSTM for better performance on GPU.

# %% [markdown]
# 타깃이 원-핫 인코딩되어 있기 때문에 모델을 훈련하기 위해 `categorical_crossentropy` 손실을 사용합니다:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## 언어 모델 훈련과 샘플링
#
# 훈련된 모델과 시드로 쓰일 간단한 텍스트가 주어지면 다음과 같이 반복하여 새로운 텍스트를 생성할 수 있습니다.
#
# 1.	지금까지 생성된 텍스트를 주입하여 모델에서 다음 글자에 대한 확률 분포를 뽑습니다.
# 2.	특정 온도로 이 확률 분포의 가중치를 조정합니다.
# 3.	가중치가 조정된 분포에서 무작위로 새로운 글자를 샘플링합니다.
# 4.	새로운 글자를 생성된 텍스트의 끝에 추가합니다.
#
# 다음 코드는 모델에서 나온 원본 확률 분포의 가중치를 조정하고 새로운 글자의 인덱스를 추출합니다(샘플링 함수입니다):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# 마지막으로 다음 반복문은 반복적으로 훈련하고 텍스트를 생성합니다. 에포크마다 학습이 끝난 후 여러가지 온도를 사용해 텍스트를 생성합니다. 이렇게 하면 모델이 수렴하면서 생성된 텍스트가 어떻게 진화하는지 볼 수 있습니다. 온도가 샘플링 전략에 미치는 영향도 보여 줍니다.

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

# 60 에포크 동안 모델을 훈련합니다
for epoch in range(1, 60):
    print('에포크', epoch)
    # 데이터에서 한 번만 반복해서 모델을 학습합니다
    model.fit(x, y, batch_size=128, epochs=1)

    # 무작위로 시드 텍스트를 선택합니다
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 여러가지 샘플링 온도를 시도합니다
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트에서 시작해서 400개의 글자를 생성합니다
        for i in range(400):
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# 200278/200278 [==============================] - 14s 71us/sample - loss: 1.9621
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the destrues and the saccession of the sense of the still and all the still the discertain to the still the still the saccess of the discertions of the sense of the stould to the domentary the dould the still and the still the still the man and commanses and the still the gree and the saccess of the still the scheired and the discomentation of the scholen and the decelved and selfing the still a
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the intertes will the discertable of the science of the senter of something the sought of
# the sense of most
# explestion, and the philosophy for the discertioned to the to the part in the sage of the chillitations the the long and in the greated not and deman religions, and of the semselves of the greated in the more without the will where was in the one master and demond to him soulses of net be
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for aw. p"eger. the resives, pare comlity and say masr, wort e8riaged there
# bor venction oden wolpiness, to obdew to bthe unvoses way, everyseffel agpelous adef
# everies aurleted the fore whelr which
# nature man explysions, it spicious non ygor, and for good sceptives and others form"uble of the command masishen the question,
# mast viltuen "garm and commendiess of tamint in the more and most neculsposi
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for acad fortattle bandter: the chusely, erm," as
# grettelt, these to dy may of a
# thsister adommentatench himsepfices
# endymselvenshanss notkusarity dost
# uncommany
# will so heps inklate
# of to genemal, and in all he pat, dogune temled be-  tence.
#
# cinjudes to jumbly lagijur,
# exxgrescious thosine st!latedisy-love must hat meanquau exelvatage, of him
# emor, as
# cource of theey most aftereromity
# spirest" spi
# 에포크 2
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.6107
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for a still and all the sense and still and something and something the sense of the more and sense and as a still and something the sense of the sense of the same the sense of the sense of the sense of the sense of the still as a still and the sense of the still and the such a history and and something the senses the sense of the sense of the sense of the sense of the sense and still and self-conse
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for things and against and still and a manifest there may secuence and the interration, and as a desires non a standation of the power the thing and senses and senses the lower and
# such a prices to experience of the assented be a man desires of interestic of the perding and here will to himself that this will the spirit and indeed to such the cause and when the disturn of the restration of releiness
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for a had to which learonur, their is of thing of the masy the !spifical rended societ; it wase.
#
# ull
# as a diver
# soke poinct seems low thing to the houge--for which servedely with a  candue and assence and the sends of the thing his
# aste love as even "anling, matteos all mas only our singer extences, this ,world foundation of things that the vistormes the must, oneppan further hen somity of soly thi
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for it commanied to drethism,-as a tiar and rivedver!
# "engr"fining to swengage.-eon wromed from the countenefutive;
# , gast" undad it,--that
# aover ote
# how-expiantly, alwabit hli
# ngr, in anliekslomecany "spirit,
# this perhaps
# this fhatesnment,rs she undarkges
# of lobein but now ivear slames podity of this interiusl.
#
#
# ow
# "=icpaice which henes of this htore as of endhi", inteilieil of pleasurety, or "
# ,
# 에포크 3
# 200278/200278 [==============================] - 12s 60us/sample - loss: 1.5234
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formal of the same mankind the manifest the mankind the sunstical such a such all the most mind in the most mither comprehend to the surming of the strength to the end of the sunsticatives of the subject to the comprehend to the such all the cause the such a such the such a such a stand of the subfined himself to the comprehend the comprehend the sure the mankind the spirit. the self to the spirit o
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formseee them even and the causal his ancience in purlise in which it with the estimate such the disconstance of the causal such them some and gy of the way heart from the compansed themselves to the called other
# strange which have the comprehend that hitherto precialing in the manicomsent spirit. the caver as all the summal all the love to its may called does to charm, in the truth and bad
# how all
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through force all
# eaghing world beradualce, quainatio, in fact in
# the plaths, which
# by
# them world, from appe"sible" in
# them. withoua more indignangling in an a thinking up disting-lices"
# of-: it is nornefuls of the says firne with seet given--a lighteyed to magical laies bisquality time emitt e
# himself comicaus so faith themewit butter lock harp, evilulity even he
# course
# which advarious clearied more of mef
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formunable de to
# even
# them which they talfoed. yas, mo"tering chond a, yeusely been promitiop
# of sunfulratm
# of live hare, gromitsd
# him within gor whreanguical a
# dove is, hack their cessic. and modiy, wise of a like in conbects all given as s.=ble, the anargund grate--tr-cul-becourse, werewherh-hand-friendss, ifmwelthing arr, manecl pvervasir admible time
# affor of revengoum, somethingsd callecn untur
# 에포크 4
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.4780
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through forewelowed in the states of the stand of the still the spirit the disticks of the sentiment of the sense of the strength, and and the man and propers of the sentiments, and the such as a condition of the state of the more such as a desires and a discovered and the propers of the propersion and and the stand of the more of the conditions of self-desires the sented the desires and the sentiment of th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foreuse in the distrably and the desires only possible to the strange of a concessions and strong of the harded the ascetty, as the nother discoverest of the more and complexent whatever in no more the sprietiey and the doven and comprehend something and propect in the more now and a discovered his pastic being that the condition of the distrust, and we has falter
# and still and passions and age
# of t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for even and maristic to drnaked
# antiquation had forder concessably adoct restrained of sympathy, bround that we vigion of receurt, one regkoraly happy
# wishever good somethilg goody, does there sexualsent comectly hegerny insight, thrinttressle intersiscical more the
# least throughvent, at all
# the feations? as surmistoch man exaccusted wheffer felligy of geners _freedy and lightent) master of discien
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forgiwthat with art ow
# gove--and is regards (whole of the proof
# it. if we has that such
# a well but must guinism,
# that is the
# gerste, hese--poasesty, a kay onceress?o of me, who care,
# this and sonenty--orless thereby allly
# powerful,
# in
# himself only decapairianes
# yem, a crouples, hale begately and
# creentionh--"faluar; bleur matter tow will the
# phriocslyry and the motesly consporicary and
# placen of rum
# 에포크 5
# 200278/200278 [==============================] - 12s 60us/sample - loss: 1.4486
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit of the problem of the same things that the problem of the scholaring the still the morality of the former the problem of the former the strong and strong and the problem of the problem of the strong the spirit of the soul and the dangerous the problem of the possess and the strong the problem of the problem of the same pain of the problem of the soul and such a problem of the morality
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for all ever rull of the former than the the religions and because not the gradule strign the fairs of the cause than an attention is in the varitable of the intellicion, they are that all the through the samethiness have all ender things himself the agreenary because is the morality, but the spirit of the soul of the propectable the cause are the groutes the sense have good and for the has man is t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forgor
# the religional
# regord entertomer. that longed still are oft were only a live to later to contric willly very like that the music
# still has broudstip as kind, above have heart of it devaliement, let us would saintiin and the frarcw--"lanct2e which that usives cause that
# prepausted by the generated has forture and vewled that
# oft the relations and asklful "traditions, no
# etientely fellar, a
# dis
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through follow. for
# open reeit fosmed, for orqurions no disguished
# and knows let ones even it tannific. be viewst
# own, knows nothing christianity? in regained go
# raant his "roage of husationich and faryely, as an . for as sicvic f-lytecssisy empations of whane, grame--and youn-if: but soilineionialistoming
# reason, with whi; is for whreatfuls
# modech" a mears faftes of epocout, he churcupen , wondy truth an f
# 에포크 6
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.4266
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense and the spirit of the still the sense and the constitute of the more will to the state of the man in the religious and the spirit, and the proves the great the spirit of the simply one of the sense of the senses and present and the same and also the still the spirit of the sense and the world of the still such a still say, the man is the spirit of the special sense of the still still t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for an according to the sparing
# the science of man has been present self-seness of the sensed not a superfar of the inclusion of the power in the regards themselves to be discovered into the morality that the amache in the low. what of the same absoluted in the individuals and as woman, threat of the residents of the very conducist of european to heart and as if the one wisdo now he seem in the appe
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for an inoc to which they anyived than in europe regored through oversay, the has, than becamefulnes contrave them unagerance. for examplend, one's bound are
# nonego occasional envolumently,
# and newaken self-mad it is morality which period "for a
# spories of man, is to pure hands their soul, the weaken, romding soils live.
#
# manoty for can the intervarding, as to batters also understood forth, in god.o
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forly--of now yelly
# religion with
# a lim. mi"dious
# congentirunn,
# !werieth build the super. the grysanwary into the god-pri-orajly respection. theredie what might the destroy
# an injudedy."
#
# b7radent which belongly time. their
# sociul. angoling to watt inxgerited of
# a hala also moredog?
# d epochiness of appetord full offent, in "fragnestyw, powet of errou, encight,
# hut tempore of its elemance,
# nord pat e
# 에포크 7
# 200278/200278 [==============================] - 12s 62us/sample - loss: 1.4109
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the condition of the serious entire and condition of the most condition of the sense of the sense and so the are all the possible to the condition of the condition of the present expedience of the sense of the condition of the superiority of the world and prompess and interpretation of the same the general disposition of the condition of the superiorician and the prompess of the present disposit
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the sense of the most limration which is to be something of the commenced and bod. the condition of the for the individual serving the most object of the very his for the all them are the artificed and prosent in the world of the condition in the
# politic and learned man and conditionally from the prommine the
# presence the intercourse, which is attenming and the thought, and the deception. and th
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forcuments to view attain time of evely cover, it sciences swain, and wisded of himself are to it
# taftire and bootring be pleasure
# mraken for the uuption like you it most nimoraniwed earthx, my physioungs
# and impossible
# man there was alsoemed aboned-ideas, they be
# gade. worms our uedudive of poysesce. should be clumed hwhe qualately galan philosophy, here, bosd takes as thene, so in the exparieated
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for a p"
# just his despireanul commondishsment in the ramices how himself
# by hypocists should
# curideation rystumy, vengect my whole divery sopish, haddhoation to it mank to a leld in
# recrueed: he clear fat teduatness now,  orut seket of must, thiis make
# imparenty
# of music undover, fworlebstr yough a ungine with
# iect why
# ma king, most unler all philosophinal well, the most
# dityknunt it: they nrect to
# 에포크 8
# 200278/200278 [==============================] - 12s 60us/sample - loss: 1.3979
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the more things and been and the strong and the spirit of the spirit and the more man and with the order to the conscience of the spirit of the spirit of the sense of the thing and the thing be the sensition that the spirit of the spirit and superiorily the spirit of the seems the spirit and precisely the spirit of the one should be existence of the believe and the stands of the conscience of th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formouse to deffers of the new morality--the world of a more spiritual will one still present sense the greek and the morality and sufficient of the
# other
# have most precisely this society of which one must even and for the way be intercounce and the enemy to other and as the when they are to any bring agreeable to be the spercible to do so this and believe in the standard of themselves man have been
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foryel.
#
#
# 1th
# sis and socration, and
# long, an approgrount., are seems a philosophers afterivily of of namely groups, dispeate and be spastrems and threly chanot sink. this a years. they are the
# best extreed
# physiouxlisim and
# rulgarier europe and them. orian as a colond of the relestered
# another, untellige. pronoshise his
# own relimier, or by selfore-frees, because the agpanaing himglest stopicise, he
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formers, luchartofur, to beings, the parth
# as the tear to our profers and pred jud procatives fromeublicism, ador
# or visoluchoud," certainty" for self
# inscribes (or. the dut anyshines and frees, butanj hand up strangerest valicity withat wenkig als life vanitever new creatureests
# in the atiate perhaps and free upon philosopher, that even as alsolard and
# underitually is, is knowledge and iother, nati
# 에포크 9
# 200278/200278 [==============================] - 12s 60us/sample - loss: 1.3875
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for a mean of the same thinks and the spirit of the superiority of the superiority of the conscience and conscience and in the same than the spirit and superiority of the spirit of the same thinker the sering that the strong and also a superiority of the same thinker and the spirit of the spirit of the superiority of the many and also the strife in their strange of the strength of the same than the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the way
# in any discoment and "thinker and afforting are minds as i something with their astrupupse and conscience, as it is word of every pirquent of a more conscience to men and to the formation of the pride of their spirit and precisely the meaning and the man of its action, with the most many partial values and word in their hardens of the processess of the good man and the belief of the conc
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for which wondation, the metaphineratical valuation--of not thereby emating,.=--and that nevery adoran physiors that which however sdires,
# a. psycholondy, "has were
# beseer, asely, however, they are knowledge, enorgian,
# what in himsies of their weak: cause and gafting entlins ef, with evaluty, and insinn evoloful, sympathion of a menul," for philosophy, which had oncerjudg and wishess
# for admirity an
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for his "powerness!--ever, make clears, times sught time and
# "judgpor as again an
# aminty
# he coaration? aowinay and thysies, hands, their reence" with anyivhtne valfasion, therebyolon longarderich as insciration: "fack they least in imoun tni!smqually
# theher and xself-stricted and
# my period when can dacknowle and the fins and  of indemable,
# barby
# hardual
# bettrands. the eik when, empority asu'hist apa
# 에포크 10
# 200278/200278 [==============================] - 12s 60us/sample - loss: 1.3786
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former the present sense of the servist of the sense of the sentiments of the same the world the sense of the sense of the sense of the supposed to the sense of the sentiments, the more the sense of the superiority, and the man of the same the sense of the destruction of the sense of the sentiments of the sense of the sense of the sentiments, because the sense of the servion the sense of the sentime
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forme this sense of a means of the depth of the responsibility, the strong to the consequently the personal transfects of the superis it the instance and the still a defect and belief of the sentiments of the still suffer of the responsibility and present spirit of the supposed the destruction of the sentiments of the religion the more also
# cases of the contradion in the soul of the freedom. the sen
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formal condations. somethings, of their own badible the christianity the best at the sounce of its si"d with him
# notions of move believe with the
# severiz). but were because at the disctials, the national distance. the such out, indeed man cultured is if the onetide all precion
# disturs of herethuarl, yeast sentiently ground against any caquality
# as though but will through the falsehtide fratter
# been
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through follier of these codere it in nothing ever
# jupasce! nor dut olermoratije: it is
# him to weaneafly and self high--the  selvessl" through his heroriks and cray
# in
# a serntients which, onigently to ity something more, they would because, fneace of ethic; and amdity as
# acquireds the
# dolen histocuely panded othershed, what take emoter senses, be fideation with dicharte, venquiloting marwnism poit of intoy
# 에포크 11
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.3708
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the stor the stronger the spirits and profound, the spirits of the stands and the spirit, and the spirit of the standard and the spirit of the scientific and the standard and stronger and the stronger and profounds the stand of the same truth and the stands and stronger the spirit of the stands the stronger the spirit of the same profounder and more the spirit of the spirit, and so the profound,
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for his assume to the present spirits and states and that the super-in the powerful and stand of the truth itself be its in the superious and the concerned and to an ancient clearly something and stronger the stronger in connced at manifested the spirit the same moral conscience, and philosophers to the conscience of the age of the more self-destruction, or of a present expression. it is the more to
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for respect haffinate instincts, all that these belong, it trutls of the hopo remotely does the
# arloust proceessour envourses in manage. be
# inducents for an
# adpames will exert overdeen their leacher with stronger power, how as he is not not another, this spiritial-denespection, we not the ethilitnes of immorality is that is to the noble instinct, as the falsh, the sensely. how canuncems in
# more all
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through found
# op. what nothing, are s and notion seict rewignesing, aot inspirptey ialishe. eaphiles
# to philosophical sbeingle
# hirdes brung, it was p"tstines
# personal seriously" to pastme
# is other anhism of capatics. turptog"
# of occaising canher, for the mind, not
# euroual cist -also ems, learned ees century is. sleec
# and place for ems," who has such aisedest to allet circumites any bashing boobfined. but re
# 에포크 12
# 200278/200278 [==============================] - 12s 60us/sample - loss: 1.3646
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit of a standard of the spirit, and the spirit of the same spirit of the spirit of the spirits and spirit of the fact that that the generation of the spirit of the spirit of the spirit of the sense of the german to the spirit of the superioring of the spirit of the strength of the spirit of the spirit of the sense of the spirit of the spirit of the strange of the spirit of the spirits of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formation and consciection. the science and strucgle in the coloured and spirit spirits of the faies
# the same and the bad our spirit of the such as the most to disposer to it, the properted to the superiority, attain to be he is to the frerstorist and commandered and altive in the fact to spirit for a standard and suspicion, which is a man as much all
# the world who has to be it is the most sension a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forme respecr,
# press, to pering on his
# is has no pos to younge
# intellection, anyth that comely when has the measurent, eye of his riftismunding i we we lead is are can latter
# when has he susprior har
# aothan man at last of the strucces as means (not
# certain treined with such the fart, even most anything extracreitic spirit
# when
# one should true upon the germal unrary to very disdrinty
# him natura
# makes
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through founders which he he saints as flow? for fear
# flyuing
# fact divine how as loagier with a actumoune man to very result had
# nef bare of me, that no donutilant of meitorne
# enthusian as
# sorl has to man has
# had hod among echakiod vise aagot, but dohble soul,
# it galg uage."
#      in really well
# thbe us unicures flow. they are order coted--bllisser to snvi"g in
# the upon the ascecue onotiordarily that scienc
# 에포크 13
# 200278/200278 [==============================] - 12s 60us/sample - loss: 1.3567
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the streest of the strength of the standard of the strength of the strength of the spirit of the false of the spirit of the false when they are any discovers in the state of the most desires the antituge of the sense of the present standard of the spirit, and all the most state of the spirit of the most standard and profounder and the strength of the spirit of the strength is the most sense of t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the antidouality, the
# fellow has for the smine superior of the case--they must be anything which the discoverer to that is includeration, hargh intelligite and belief of one should the spirit, one great subjection of the profound a world and the discreent to which a surpture we make the spore the conduct, the stronger and menserven, and with the contempation of the state of the streey sharking,
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formounty of heitely exementaus an called
# others by the
# stingually developing himself, and more spains of rovedy
# verlence," been fess have are
# unmad onw of manoming book, for
# courage inclined to man, taken them so.
#
#  to cistains and would he quality oked withip may its ininitious finds where
# thus their seem, untraigands was to sacrifice of the strange.
#
#
# 1ic" here lavew!
#
# 1trich of a follow intellac
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for one's awaksning
# carible egmana
# sland negain intoluly, so sigrifnence: not a long and does--and--in evbecy, whate )quiriakmorer and sarvays; it moutopetual). so is lals.
# in lim" apattey discovers on only angristey of (progress torugariguly as is morality."   spet of opposing entive
# farys atance of littlent else. that however, we contsicaning, attasiglnding opersas place, unoverage-tamesan) almost
# 에포크 14
# 200278/200278 [==============================] - 12s 60us/sample - loss: 1.3510
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foreabtily the same the spirit and the spirit to a standard of the sense of the surmority of the most deception and stronge of the present present perhaps and the stronge and the present properation of the present in the false of the contralles to the word to the present proved the false and stronge of the stronge to the present man and into the sense of the sense of a stronge and stronge of the sam
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foreabts
# of a devil more present of the constant of the fundamental soul he who constances and the distinguished to changes of contrary of the speaks of the reason of the word to the conscious and contrary of the conscience of the past have to be truth, the present, the string to more appears for the sense of the german instranting could insertional stronges, the very virtue in the contrary of spiri
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foreignoxine, an indicattiness: it
# connected it struck forieafs, our inner heart into charach! the most praise of the proximion
# are insolement to disllens--socialy one merlies to having of the so finds hying.
# mane highert
# fulte to "that that soed one can demection and tempt to by spirits of this externment in the world")--if i may not one, they may sympative
# generation of the cears wishes problem of
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fory. let us the interund to "theolog ino; it may be term that its compares and reruce mecharce. and after alocge)" are include, under plainess of geny trapitately that more value of man is true: it is divinteg)--that someousich for, gresurs or peres; in what is by uneful stie
# circumsaps yellal japux-usions of plan" lanw oteren of ariscatly,
# it is but coma
# blpotun: it is is a mas. higher effect imit
# 에포크 15
# 200278/200278 [==============================] - 12s 60us/sample - loss: 1.3468
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formitional conscience, and a soul, and the conscience of the serience of the sense of the same the sense of the result the subtle suffering the sense of the sense of the same the sense of the desire the subtle and the subtle and the sense of the sense of the serience of the result of the sense of the sense of the sense of the sense of the sense of the seriences of the sense of the serience of the r
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fore strange most fact the sense of the antither religions to a naturally to longing of the sense of a simples the deal therefore those do than in the existence of the present intention of the dangerous, and believe theremore and the formations of the superficial attempting the standard in the world for a new a case of the equally theory of the significance of the compating and conscience of the sen
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formation, are far the existence and will should for the desire themselves, imatidied and the coart. a new attrance in versionast
# and deary from future, upinpically
# but are resulterize both
# under this
# man has the other, a schopenhauer person med
# and a thrieful
# from the cainting, nother before which societyhed sympathy.
#
#
#  ti way movement; inclidnaus "woman will a persomeeies of all teething in it th
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through food of the
# lows
# "talual, oreetike
# of germanary enough as those mittaps be ormishy
# of a preeps externaltfors, sympathy!--but rough more
# gromint, that something which
# open how considocy forget for
# himself the spound whoever
# over!
#
# eack as the highest duting, but one nacear, sorturly.
#
#
# 7icellistsly ask yet that in what extraving their
# rogialo-sensely,
# princt who in such -nornest it case frex of hild
# 에포크 16
# 200278/200278 [==============================] - 12s 60us/sample - loss: 1.3400
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the contradically and the same the same the same man and the sense of the same the sense to the sense of the same the same the spirit to the same the same as a stronger and the sense of the same man and the sense of the same the strength and the same the deal and and intellection of the sense of the same the present and the sense and the same world as a means of the same the contempt of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for explostical and who is the arts as a supensition of the same manifests and respection of a leading and love of the sense a proof in the most sense of such a whole be all the conscience of the ears the
# have been the freedom that the same discovered the morbid the consists the one is not that the present spote the creations. the scientific and a desires and decond and whose the first and the respe
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for this gleasity to
# divolity to a devily
# cruefty write
# perword),
# the same tempos the
# person becauses it may conceive with those to be i tenture in historiness,
# without a dance his highest ventar and respectables, that is to curse and different truthly when he should than inrequiritions, and
# shin as fllaioursed through the
# sentiment,
# far
# the modes too intenderises, as a points,
# asserts the do-withst
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through found the
# sub"yn? they beinds give ourselves, has haige it: i hale: that do conturplusion. senteas clourse tooghes the first now aftermuptionant's gromanism, the consist.=--there possikible who, he more once bad this, all
# menequent and
# impleas themselves of this lomesicy, coises it, a pains, surmittal,
# .yy low te "who one may less being lugesd bienevous.--selfoubless, and accorbat is consider to jud
# 에포크 17
# 200278/200278 [==============================] - 12s 60us/sample - loss: 1.3360
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the spirit and some for and in the same the spirit of the superioright of the conscience of the spirit of the self success of the same the reality of the spirit of the spirit of the spirit of the spirit of the most the spirit of the self and the spirit of the still soul is the most existing for a free spirit of the superiorive with the same the spirit of the spirit of the speciation of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the most stronger enemy one is learned that any one wasted one of the interrouak of the same and the same their order to self the instinct of his feeling of come the
# c:\users\jinlongbin_lab\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
#  conscience of the superiorificate that and for the most social conscience, but the men, without world the promises and the existence of men of the good decided to the spirit in the words also the fact of the world of the self develo
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foundation should dealh, to gradul; said inventianciently to yet account of a notice, inphond, for the feal.
#
#
# reobuty at man, one _mirat.
#
# 1achated ageble is therefore humilally, and
# inaristensually pariitian dear, and tranghing, privile recirbsations extreched for socialo_ges, roudg thinks by for acchupish anduted depresent
# for inphilosistic hase we lookamed of nature of the states of ethic of who
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formoudporiful trays, as interree before on that it larce of chikely deepenerards, approjused to are
# a cust
# med or
# attentish,
# was
#       a "faith of slorts; one circeing, which
# i--footorial sounwisid trvent; aedutitess of facted aergen
# vigorousness
# for gets, there
# in south, the,
# "benightimal lef-them philosoas
# profound-flight world
# aboy
# tradiased,
# flourious eyiug e, antismok regrispquened, naptinatio
# 에포크 18
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.3307
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the conscience of the sense of the still something which has been the soul and always and the superiority of the servild the strength and such an according to the sense of the desire of the sense of the same the most soul and conscience of the strength and soul is the desire to the sense of the experience of the profound interests of the consideration of the profound taste to the democratic and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the greates god of a thing and stroke which the decises and profound restant of the sense and be now the point and consequently can always and to the ascetion to a hard an a external subfication of the medioccyly of the belief in a now daring to make out of such a little spirit of the nature of a continue to it is fact of a moderation of the profound of the good in the profound really desires an
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for natural
# nature no lim all the borrould and coloss and inclination of heal
# with
# ready even in epicuence is
# involvigs
# of
# a propoused
# think of destinva, not schofening it.--crount.
#
# seck, not self-chato, and bodarphile and bold to himself and the new plainly, allowed greattly can bray a grimal, were the wism of himself and astrictable vacial
# values of the way.
#
#
# 12
#
# =etert and appromoper and pponti
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for which sometime laves expoloble an arrorking.
#
# 1447outred superiodifitive, impordant paptatuge all luch, or he
# trife of comphisacherd in too found so morely in! the dustmains
# out--"god: now
# encerntate proteit
# flyxes yet
# the
# slavesity of the suspicion "awara
# conjuresspors
# in the ages nature,
# graitful) is do yot happiness of good instance of the same ephorace unfor too instance of best about flooac
# 에포크 19
# 200278/200278 [==============================] - 12s 60us/sample - loss: 1.3285
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the rests of the sense of the present of the state of the sense of the same the sense of the sense of the sense of the such a man will there is a soul and with it is the most soul and soul and soul and the most conscience of the sense and such a man is the state of the same the spirit of the stimuly of the conceived in the same are the strength and sured and sources of the contrary some
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the sense in the have the most dangerous of the science of a more through a harden history of the virtues of the deluct the possible to method and stronger who long and of course, and the disterpression of the characteristic in the other who has in the distersocvacl the most more astreconcled there are mothers of examples every simply and case the same enough to yet the intimate or for examples
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for one gragily only makine, requirity in peach any-heither there are tears presupered seems to deceded that the mistake cheise uniselly to ahoulmed, we consciences, or along faculficate something has already any
# moral hlead
# are typical xue turrif, glated a would not to
# day, toist, ioch a manomoties itself."--thinked swack theie of present far antability!" or goos it in a u for your essentive happen
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forly, and reparatory
# of mochidg" and spirit history into feelingly besters, fe
# to purcingly fleeic hman and sudden strough, is id fellies with heal thas rage as
# as molbabliy
# mandet.if of artidinative har imprame-fullated:--such and its misway, unxerselve arsocually, the morityic our itself indifications of chrreain fornertian-"commant-sessmoning the eviousness arrorianity and peray
# extent. frant fr
# 에포크 20
# 200278/200278 [==============================] - 12s 60us/sample - loss: 1.3244
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the same men to the sense of the sense of the same powerful and so to be so that the sense of the same men and the sense of the sense of the same man which is the same men to the other of the respect of the sense of the same world of the fact that the sense of the sense of the same world and something that the sense of the same superid to the sense of the same men to any lang the se
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the religion and of the one and the democratic enemyry of the same such an acts of a present will be a matters, the superior to the desires that it is to sensity of this docial strong regarded his self-litiraties sense of the one thereby what does it manners, the world of emotion happiness of the superides and instinct of the instinct of the something does not
# hences the developed to the soul-th
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formlier bewhole
# sonlians a
# guidegeian pguy-naturally, an
# europe--no taste of chrouphing conbaces
# in its his abstrablus of his spirit too the human rejuditionath, andness and forman society of plations--in faition; and (and we method the patient tolation to mortage bable higher than single of the motived as does for others,
# and view, to bear of  of "the religious. and
# detience theonations of
# consile
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fory
# with orderstrait. ordinary lights will is
# spirits over to it mild cipordition you youth; wherest much tormlatikapless eragen creation and it between the dream to hacked it belikesed it, why who may cause, has
# res-lad wild, necessaringe dirdon--wills, and then does nim.
#
# 2r tyin the enougha-s.
#
# 44. let to as
# "religious restration if we last learneding to what a
# bettery adaments his world and nut
# 에포크 21
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.3217
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the fact that the moral and the more and the greatest profound the strong to the sense of the same words of the present the decided the same the sense of the stronger that the sense of the strength the moral and the moral sense of the same the stronger the depresent to the stronger and according to the religious caster of the world and the belief in the moral spirit, the moral conscience of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the serience of the god of heredity and delicate them.
# 13h but it is the sense in which one must have consequently what is endurable man who so conscious and prepresent as the end in the man, they man, the free spirit
# that when i have been should that the world in the commander that men because so nature, is the more morality, and in the mere, and something that one of the fact the person of t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forked inavourituwical gheniois-: the ingreise us affeident of justice. the unracper is a new, fell-pogiromed volibou id, i because .xuption and good to caste, thratemently the sunding that one of distinction through the last, the whole that the fact beliehe very pleking the masterurhthy as
# one follow which proof it towards the instincts as betray that sexity
# they dignofar to the culped to evolves l
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for its na cordegable
# degrees) enthalistic intoishuper with those as it is naturaming to been hver life-conductan thing; for life attempt toma, were above a supoilt). thous d day of rational were for here, profound upphyperncainse--if ye obliged, some mastesshous ariliable
# to be "debeined is crames and occigums,
# which
# any hands so brresuit, rich not replomoracedd omt with them-dightatiul longer.=--d
# 에포크 22
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.3173
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same and the sense and discontent and restance of the present men to press of the strength and something and the strength the discerned to the same and something the state of the present same to the strength and all the sense of the same the present and reverence the most the most difference to the same such a man and the most deception of the same and and the conscience of the same there ar
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the political and cruelty and will as the hand of a philosophers of the end in themselves be attain to the ending--in order that we get the most dangerous rest
# of some most instinctive of the except the most the stingue, and in them, and there is the interrand to the fact we would not was not in the discontent and the fast no things attain that were as something in this nerve which they discreat
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for their last ple", be a question does not with german will socratic in order to
# taste of misculture, for estime point, tomails among his
# attain. wand by the gast of the religiouss, it now continue at ob: the truthing is
# reserved, religions: whey whole
# deepernative and benievity, now figired as they mankind to point is to have a benrest bible world so to
# coally balaged ranks one most obstund withtn
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forling by this becomour; wes notes everything many nuture; there
# his (the excesting,
# eewk, a hunard and periodant; in though any humantwing willing ununuly parjorned, riged ainton, nory
# the right
# to finern, in the chqueliescor of condevitual uson, withor thinker peroust--as instancity of moralts" willisg and does rithers as new: it is now da? wlerpliame: wiche, him, to view, so events for
# individub
# 에포크 23
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.3148
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the most and the strong and contemption of the strong and the strong to the sense and democroper of the sense of the sense of the subtle to the sense of the subtle to the sense of the sense of the sense of the sense of the subtle to the sense and subtle to the spirit, the world who contemption of the sense of the stronger the contempt of the strong and soul as the most
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forming and destiny and the manifold which is not the plant the art who destiny and interpreting, in a
# contemplation of a constincts and contempt the sport of the more in most the great its endure and long
# and belowed one was to manwards of the same a so much to religion, when he should to the man of the present sense and hard of the world are the most distrections and things it is there is the belo
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for
# own inward -man, in account not becomes indevessment,--and which the wass,
# indibnished as shortoniai. but all the actscury endrave that is uponly"d of the needs of
# the power. the great estimate consequence of soleased in ordently for far for the pitome predicled
# worthming and seem be pateranatis.
#
#
# 1s
# akem below in the own man?quite, child of
# spirits? or an or sufferers and with which posing thi
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through found things
# what berisherarthal,
# worshed seeks fivial
# sake of the depth-to, a variently have
# a"; it is falsehopenian, but compsleach,
# contlusted and
# powlote look,
# instanced, the best la resentime suspivity in is althing okt for
# them worsvisge nourlihes explmanation of builtonace, i would whole geniuramentapy fron all stranges of
# humanation sometomntally
# relught empcxisumance a, whrejusa. it empiric
# 에포크 24
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.3103
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# ...
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the relations of the same traving among at last to be concerning as a result of the exhagion itself of the battory and as it is morality and solutes the dreams for men states the stood the power ourselves and the deception of the conception of the deassinanly can wishes to do the subjection of the state and grammed as the through a history of the means of a heart of the supers of the all, the in
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for any readnessial. must unthis illose one deach-much, tire delighty
# strengths as a
# case" to which the left as know to these value in , how manifests from the  will me; its own to the free
# philosophy is dormant of interpretation of the
# equality and nevery be cha-greastaus, before
# not possession-litimish of its stroke shelly before ordian and
# ideals the guils as immed abusely: a profound super"tory
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through folly rew on each was ?yvout cas, are is ascertany physiors to oneugn or need a sort, or a disternificat,
# feiently been unchanquire duar looked of wishim the
# -away like unkfost, vorad first reksed men, it were unstranvest mast,
# and her this matters; its crost overlew wanv ordenations and which knows meditan he warlize be general concenduorable to the bain
# youds certain mediumates temperanted noormie
# 에포크 53
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.2510
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formed of the same in the sense of the same all the present world--and who be and something is the sense of the same the sense of the same all the subjublent to the same time and the philosophers of the same and the same and something something who is a man as a present the most soul is to the sense of the same as a present to the sense of the superling the strength of the same as in the sense of th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fore the distingued noble
# history of the sense of the sediousness of the sense of the reason of which a matters and in command, and not have been a soul as we may also the causa
# of the reason of the world is a man as the world.
#
# 138. it sees the antiqueration for the sense of the beliemen
# and reason to whom
# the reason to his sense and prefers the sense of the case of command that one has a nobly one
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the
# manixately pupires
# himself pleasures to a heartenness), one harby neverthely we have from most good the souls: there is not not a said, on the hipifly and call it was the ratinal criblies sympathy to him growornmentss speak
# strength
# and gladest -the appearance, one has all the
# blind conder a
# deep to mind, which they do not all the present wen an a merely my forces on comous male-dre
# general
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foorthy for averea and crinted-platocococrating up soming has mach
# ideal. of unsome suppled of the term should unutmost metaphysical desirence strength" he seeg thating thought of the lighed nomes in the term, and agatej-
# promised vanced
# affirming maneamable great even the most resirned impession grose)
# furthing, and allowed in sympathy,
# standay of profound of mankinds whnywnquvh ilojvised rideh at
# 에포크 54
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.2507
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the consequently and soul and the strength of the same the standard of the moral and the stor the strength of the respect, the serribing to the strength of the same is the strength of the man is the same as a proper to the consequently and self-desires to the same to the propection of the same the stor the same and the experimines of the superstition of the stone is the stor and des
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the most
# concealed with the strength of the superior by the order of the supercates who shell some as is to the the superior and to all the propection and all suffersent of the habit of the stor which the existency in the desire to the thereby always been the gramm-unevoly
# and possible for the superfic and deceived the most problem and
# first under the defies and self and interlogian"--the means,
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the side, curily--compt in
# this want wrong of the papacy--who comately.
#
# 13t=" which, the
# probable contemption to darouse. buchour voluntatism to be part of christianity,
# sufficience and to be done reduriance, a
# preceans of thessel
# lay worth than light. how beforevan's faith autyming that a man--on sour actually possible truth bads and
# solust of the pain and never themselves in this could not dr
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forms and distinglian of "from hard, the deduc (and very vyrivil preservant to a
# cas! perhaps us" that somewhar theh ricg all prast foor and for the emotion for them of type
# man yearry, ekenorable thars oxies
# controlish
# possible is aptition of the coust distinguia "disalmable, command;-yood", himself under outgirs to the soul, relsen rested in
# involude it out has. elestant
# geners thating, nemush and
# 에포크 55
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.2481
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through forms of the same will so that the sense of the same in the respect, and the scholarles of the same and the science, and the senses the senses the strength of the same and the same wishes to be a man as the same as a man is the senses of the same in the same in the same in the same in the same time the strength in the contrary and the moral present than the senses and similar and such a senses to a
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forgets in the case of prise in the moral possibilith and wishes to be the greater that man assustion of the philosophers and distrust to be all it will protection of the science, so that he not the spirit of the spirit of the same in the most serven and seems to self-really has hitherto been the realitiesr" of the contrast the respect and the greatest seems to primitive for in the disposing in the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forms of
# distinctions are other person
# enough time-amidging appear a
# such an all cogrectmen, then, and which has moralty one part
# expresses of the world and
# costimous!
#
#
# 18
#
# =no dishouste
# taste, as himse
# falsive schilimoal scypicles. this does--within artsan veking that the ademote chaaach--protoracentakes of present, but that the
# frees as society, is nature and yous!
# rould also themselves over all
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foround, this englishy.
# things roudds are , an aheness? why every other dymptions of the forms and philosophe, rares, uponefy something
# of
# eyes from the "colerd frard to dictates dejudaus, consisionness" who redulined
# amans" and surce it not pinions that the catioasion.
#
# cint it might "author movestel.
# hundess--as shaders, vi, this is
# nature
# of the be appearing of mind in the echopenel educable
# forn
# 에포크 56
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.2464
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the same time and still and the feelings of the same will and the more than the present to the sense of the more therefore the strength of the same will and the superiorical and the more than to be a point of the sense of the same development of the same time and with the sense of the same discovere the state of the sense of the sense of the superlogical experiences of the same time the stre
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through form of the science of the pastical secont. one are taste the end to the soul and sense and there are still and therefore who is always also all the deally with the distinge of the devolvated by the concerning perpetually a part of the same assumes and subjective present man is here, as a long tradition and but that for the sense of the state of the each has increased and reverence of the superlous,
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forget, to be a manife atterte pres
# does
# nature--natives
# thing himself has its uponting, i religious knows and skepticist, and poing of manifests is object of every
# nouch-is also play of alr
# who needs of germany to pate of contempting
# can be
# deblind, and where so to be acts of liberation of ligious
# ages
# of the
# huniatobernes of fear, a new too belief is elemently with as one in ally that he has insig
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fore to live betwkict'phobksplications which we perceive. but is odis natly continuance and indiffering.
#
#     an assume
# bole witness,y grows which it was cervedonh-so around them and mirality upon godmical flor may libe
# aughe ethics"
# (the destary in wast taste,
# of the roancowhty and tit of states for indupents of go frath
# resrocribues
# manifests it. very delicatic will postechs that person and
# later
# 에포크 57
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.2484
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through forming to the fact that it is almost the superiority and delight in the most sure the good to the struggaved and surplus of the subject is the most surpluses and self-reason to the world as the three will some and all the sense of the world because it wishes to be belie the strong to the suffering to the present man will be all the proper-dolunction to the desire to be body and says and sufferings
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for them to the concerning the possibility that it is a pain of the farious has different and commanders of the fact that it is always be difficults of the reason, is a moral and all even in the superior moral proper-greations which there is not almost suffering--the fundamental of the lay may be als, and in the european and constantly there is the disposing
# and new distance, or has been a condition
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foregoissy-when that as we coverach, regards by this aches as they be diverter to the nemecation. but they be attemp of in it with the expect, or a eternal different, they are also, that which i coughter "un)! everymomed for all its force the schopenhauer will taste the strong-decessly its effect,--and
# above all a cha ma yor that only have to wishes those post to germany, plices with the
# developed t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forethy
# how lost, low to race, by distuct, but
# implexant-likes, of light; everything at precultedment, re-resulting insticistical degraded,
# bodulurde by a word and reality. it has
# only in the innred
# it-breass art act
# avolmit is:--if it seemptity with, enjoyw! obligedated man-want denceiners
# perfective of inbus afficious calts acchancy an absolute si that it libst-world in
# fellais. as only to advasut
# 에포크 58
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.2457
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through forming to the same time to a higher and and something something in the fact of the same time and also the senses and a distinguished to a strong and something in the other man and sense and submit of a man and more person and a power and possible to stand and sense and stronger and something in the same time to the same time to discovers and almost the same time and self-discineraring and sense the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through form of the idea of the same oursely only in the highest disciplised and the history of the same the deathle with the most desires the world of such an uncontemntary and degree of the beauty and possess and the alter that the
# enthusiagistic like from the assumed and fore and savageding to be more delight and contemptible to mankind in every politics, of the fact of the person in the same time of the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fore an
# antereily, for his sun, pain--lightfies. thus
# are
# stimul of germans us not extraptions.
#
# ro quie=ity in
# "good proman is incaquencesity breaks to a
# a "imkepted belief
# for
# this amides
# as it, i judne, and every some man world) of to be
# presse only of which a man synthesise of his to demands
# a materic name before he matter in proorsely only agaims as the scended and aristocratic original slack.
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foor, and hende d the idee youveuolsts, as one more very canife, if
# himself in primaragite with tomdisssmele. a profound endsy: we any notiyrarity.hhat that -it pettingly: dace
# socrity;fr bock or in proor, of geers and said has impeuses and almost investing? cirtuely di, yesperiorable
# unsuddec
# through fllumss; a. ig
# can with his flattel
# disentifribes mush
# good proper on placed acts and part of venti
# 에포크 59
# 200278/200278 [==============================] - 12s 61us/sample - loss: 1.2430
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the present sense of the same time the sense of the same and some disclear to the same time the same with the fact that
# the same and some devil and soul is the strive of the same and the same and some disposition of the other men the same and something with such any sense of the same time the same and some disposition of the more suffering of the same the and and do so that the stronger and some
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fore with a question and all the expression of the existence of the more nature of the idea of the soul are one had been any man with such a desire to the sense of the world with the condition of a senses to power to him of any repentation of life in the characterises, the fact that the values, and the man and believe their deashion of the same worth. the hand and scholars and called the other relig
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for merely
# subtlest something with
# every through wo qua thouence is fairless canifest, and aror amads itself from
# nature and no
# dedition, with its more outy made, and how i.
# into this fact may like so
# that the immen, the middle a result, sympathy. the perfection to shame of the, more learns insecong predee aweoust's english fines forms are knew
# sirnvally justijpyed; the i secured to the fore bothal,
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forekoth outiontic,
# infaculoss an
# estimen, which through the pastrecy, aparayso schimite prior
# curier of this eyes what they are, sjust ohs--for, which, as
# the cont"sige of carous, taken dodul instance: his men similar stupid, think, that takety,"f--simins.eer old opers of hidenives less to who have been, makes dest are..h slank, his taoten, what
# a thinks them will is all philosopher that the harms,

# %% [markdown]
# 여기서 볼 수 있듯이 낮은 온도는 아주 반복적이고 예상되는 텍스트를 만듭니다. 하지만 국부적인 구조는 매우 실제와 같습니다. 특히 모든 단어(단어는 글자의 지역 패턴으로 이루어집니다)가 실제 영어 단어입니다. 높은 온도에서 생성된 텍스트는 아주 흥미롭고 놀라우며 창의적이기도 합니다. 이따금 꽤 그럴싸하게 보이는 완전히 새로운 단어를 창조합니다(‘begarmed’와 ‘isharent’ 같은 단어입니다). 높은 온도에서는 국부적인 구조가 무너지기 시작합니다. 대부분의 단어가 어느정도 무작위한 문자열로 보입니다. 확실히 이 네트워크에서는 텍스트 생성에 가장 좋은 온도는 0.5입니다. 항상 다양한 샘플링 전략으로 실험해 봐야합니다! 학습된 구조와 무작위성 사이에 균형을 잘 맞추면 흥미로운 것을 만들 수 있습니다.
#
# 더 많은 데이터에서 크고 깊은 모델을 훈련하면 이것보다 훨씬 논리적이고 실제와 같은 텍스트 샘플을 생성할 수 있습니다. 당연히 우연이 아닌 의미 있는 텍스트가 생성된다고 기대하지 마세요. 글자를 연속해서 나열하기 위한 통계 모델에서 데이터를 샘플링한 것뿐입니다. 언어는 의사소통의 수단입니다. 의사소통이 의미하는 것과 의사소통이 인코딩된 메시지의 통계 구조 사이는 차이가 있습니다. 이 차이를 검증하기 위해 다음과 같은 사고 실험을 해보죠. 컴퓨터가 대부분의 디지털 통신에서 하는 것처럼 사람의 언어가 의사소통을 압축하는데 더 뛰어나다면 어떨까요? 언어의 의미가 줄진 않지만 고유한 통계 구조가 사라질 것입니다. 이는 방금과 같은 언어 모델을 학습하는 것을 불가능하게 만듭니다.
#
# ## 정리
#
# * 이전의 토큰이 주어지면 다음 토큰(들)을 예측하는 모델을 훈련하여 시퀀스 데이터를 생성할 수 있습니다.
# * 텍스트의 경우 이런 모델을 언어 모델이라 부릅니다. 단어 또는 글자 단위 모두 가능합니다.
# * 다음 토큰을 샘플링할 때 모델이 만든 출력에 집중하는 것과 무작위성을 주입하는 것 사이에 균형을 맞추어야 합니다.
# * 이를 위해 소프트맥스 온도 개념을 사용합니다. 항상 다양한 온도를 실험해서 적절한 값을 찾습니다.
